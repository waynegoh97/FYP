# %%
from PIL import Image
import matplotlib.pyplot as plt
def ori_img(num_img, img_dir):
    #plot image from saved folder
    for i in range(num_img):
        img = Image.open(img_dir+str(i)+".png")
        plt.figure(figsize = (8,8), frameon=False)
        plt.imshow(img)
        plt.xticks([])
        plt.yticks([])

# %%
#data_dir = "C:/Users/noxtu/LnF_FYP2122S1_Goh-Yun-Bo-Wayne/FYP_data/personal/images/original/train/b0f1/"
data_dir = 'C:/Users/noxtu/LnF_FYP2122S1_Goh-Yun-Bo-Wayne/FYP_data/personal/images/WGAN-GP/filtered/'
ori_img(10,data_dir+"-7587.102299999446_4864986.090999998/")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_26092/3079199252.py in <module>
#       1 #data_dir = "C:/Users/noxtu/LnF_FYP2122S1_Goh-Yun-Bo-Wayne/FYP_data/personal/images/original/train/b0f1/"
#       2 data_dir = 'C:/Users/noxtu/LnF_FYP2122S1_Goh-Yun-Bo-Wayne/FYP_data/personal/images/WGAN-GP/filtered/'
# ----> 3 ori_img(10,data_dir+"-7587.102299999446_4864986.090999998/")
#
# ~\AppData\Local\Temp/ipykernel_26092/2034897930.py in ori_img(num_img, img_dir)
#       4     #plot image from saved folder
#       5     for i in range(num_img):
# ----> 6         img = Image.open(img_dir+str(i)+".png")
#       7         plt.figure(figsize = (8,8), frameon=False)
#       8         plt.imshow(img)
#
# D:\Anaconda\lib\site-packages\PIL\Image.py in open(fp, mode, formats)
#    2973
#    2974     if filename:
# ...

# %%
data_dir = "C:/Users/noxtu/LnF_FYP2122S1_Goh-Yun-Bo-Wayne/FYP_data/personal/images/original/train/b0f1/"
#data_dir = 'C:/Users/noxtu/LnF_FYP2122S1_Goh-Yun-Bo-Wayne/FYP_data/personal/images/WGAN-GP/b0f1/'
ori_img(10,data_dir+"-7587.102299999446_4864986.090999998/")
